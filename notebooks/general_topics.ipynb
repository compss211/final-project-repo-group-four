# %% [markdown]
# Whole dataset - run bertopic

# %%
import pandas as pd
import numpy as np
import os

os.getcwd()

os.chdir("/Users/amymiao/Documents/UC Berkeley/Fall 8.27-12.16/Applied Computing/final-project-repo-group-four")

# %%
df = pd.read_csv('data/clean_processed.csv')

# %%
docs = df['Lyrics'].tolist()

# %%
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import numpy as np
import random

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

stopwords_nltk = stopwords.words('english')
general_lyrics_stopwords = stopwords_nltk + [
    'la', 'lo', 'lola', 'du', 'oh', 'yeah', 'la la', 'lo lo', 'du du', 'got', 'gonna',
    'ooh', 'get', 'take', 'da', 'know', 'like', 'one', 'said', 'ron',
    'let', 'go', 'come', 'want', 'toke', 'say', 'day', 'good', 'see', 'make',
    'niggas', 'nigga', 'ya', 'choo', 'na', 'uh', 'yuh', 'hmm', 'wanna',
    'doo', 'dat', 'woo', 'nah', 'whoomp', 'yo', 'whoo', 'whatta', 'wa',
    'johnny', 'boaw', 'th', 'whoa', 'eh', 'ooo', 'um', 'dum', 'thy', 'oo',
    'the', 'on', 'and', 'ta', 'pa', 'oop', 'ha', 'bop', 'ah', 'yah', 'shes',
    'aa', 'im', 'ohoh', 'whats', 'huh', 'youre', 'dont', 'self', 'isnt', 'yeh', 
    'jo', 'cant', 'hes', 'uhuh', 'ive', 'yah','hmmmmm','ohh','woulda','nae','lil',
    'chh','ayy','aha','dit','ding','ling','feat','justin','mbabarara','rainin','burnin',
    'em','drake','sylvia','alejandro','mmm','whatcha','somethin','rumours'
]


vectorizer = CountVectorizer(
    stop_words=general_lyrics_stopwords
)

umap_model = UMAP(
    n_neighbors=10,
    n_components=10,
    min_dist=0.0,
    metric="cosine",
    random_state=SEED
)

hdbscan_model = HDBSCAN(  # HDBSCAN is for clustering 
    min_cluster_size=20,   # how many docs per topic (granularity)
    min_samples=10,      # how many clusters are allowed to be formed
    prediction_data=True,
    cluster_selection_method="leaf"  # leaf gives more granular topics
)

general_topic_model = BERTopic(    # top level model (compare with HDBSCAN and umap)
    embedding_model="all-distilroberta-v1",   # all-distilroberta-v1
    vectorizer_model=vectorizer,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    min_topic_size=20,      #if a topic survives HDBSCAN but is below this min_topic_size, it will get merged into another topic
    top_n_words=15,
    calculate_probabilities=True,
    verbose=True
)

# %%
topics_general, probs_general = general_topic_model.fit_transform(docs)
# Reduce the number of topics (set to the number you want)
general_topic_model.reduce_topics(docs, nr_topics=30)

general_topic_model.get_topic_info()
# Out:
# 2025-11-23 12:32:48,100 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 196/196 [02:55<00:00,  1.12it/s]
# 2025-11-23 12:35:46,239 - BERTopic - Embedding - Completed ✓
# 2025-11-23 12:35:46,239 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-23 12:35:51,173 - BERTopic - Dimensionality - Completed ✓
# 2025-11-23 12:35:51,174 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-23 12:35:51,422 - BERTopic - Cluster - Completed ✓
# 2025-11-23 12:35:51,424 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-23 12:35:51,849 - BERTopic - Representation - Completed ✓
# 2025-11-23 12:35:52,045 - BERTopic - Topic reduction - Reducing number of topics
# 2025-11-23 12:35:52,049 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-23 12:35:52,453 - BERTopic - Representation - Completed ✓
# 2025-11-23 12:35:52,455 - BERTopic - Topic reduction - Reduced number of topics from 40 to 30
#     Topic  Count                                     Name  \
# 0      -1   4351                  -1_love_baby_time_cause
# 1       0    229               0_love_never_heart_without
# 2       1    194                   1_baby_girl_cause_need
# 3       2    149                   2_bitch_fuck_shit_back
# 4       3    111                3_boogie_mony_shake_twist
# 5       4     99                   4_love_baby_lovin_need
# 6       5     99                 5_bay_crank_watch_soulja
# 7       6     96                    6_baby_body_love_long
# 8       7     91                 7_chance_woman_girl_love
# 9       8     87            8_promise_hope_bright_believe
# 10      9     84                  9_love_ever_true_always
# 11     10     83             10_seeds_running_sowing_wind
# 12     11     53               11_country_little_ride_old
# 13     12     49   12_free_naturally_irresistible_deserve
# 14     13     42                 13_boogety_boys_bird_mow
# 15     14     41               14_move_casbah_lights_bows
# 16     15     39                          15_que_de_te_tú
# 17     16     37                   16_happy_run_world_war
# 18     17     35             17_summer_love_bye_september
# 19     18     34             18_night_older_thought_proof
# 20     19     33                  19_dad_says_dandy_glory
# 21     20     29                        20_te_mi_que_baby
# 22     21     29                 21_fire_burning_burn_hot
# 23     22     27  22_beach_miami_california_international
# 24     23     25                23_girl_rumour_call_trust
# 25     24     25                 24_proof_funny_top_swift
# 26     25     23           25_rain_rainy_raindrops_carrie
# 27     26     21             26_dance_music_dancing_night
# 28     27     20        27_thriller_pussycat_writer_hello
# 29     28     20          28_hollywood_cardi_panda_swalla
#
#                                        Representation  \
# 0   [love, baby, time, cause, never, girl, way, ba...
# 1   [love, never, heart, without, away, cry, gone,...
# 2   [baby, girl, cause, need, back, mind, around, ...
# 3   [bitch, fuck, shit, back, gon, money, city, tw...
# 4   [boogie, mony, shake, twist, watch, dance, ton...
# 5   [love, baby, lovin, need, girl, give, feel, lo...
# 6   [bay, crank, watch, soulja, boy, wee, girl, wo...
# 7   [baby, body, love, long, way, girl, shake, fre...
# 8   [chance, woman, girl, love, man, mmmm, give, n...
# 9   [promise, hope, bright, believe, church, find,...
# 10  [love, ever, true, always, never, forever, hea...
# 11  [seeds, running, sowing, wind, boat, away, pas...
# 12  [country, little, ride, old, road, free, mama,...
# 13  [free, naturally, irresistible, deserve, obses...
# 14  [boogety, boys, bird, mow, willy, bennie, bang...
# 15  [move, casbah, lights, bows, insane, batman, s...
# 16  [que, de, te, tú, el, en, ey, como, se, un, mi...
# 17  [happy, run, world, war, waiting, washed, away...
# 18  [summer, love, bye, september, sealed, sun, bi...
# 19  [night, older, thought, proof, bout, getting, ...
# 20  [dad, says, dandy, glory, joyride, laura, make...
# 21  [te, mi, que, baby, se, si, es, pd, quiero, am...
# 22  [fire, burning, burn, hot, venus, heat, desire...
# 23  [beach, miami, california, international, baby...
# 24  [girl, rumour, call, trust, wants, knows, ho, ...
# 25  [proof, funny, top, swift, taylor, williams, k...
# 26  [rain, rainy, raindrops, carrie, night, window...
# 27  [dance, music, dancing, night, groove, rhythm,...
# 28  [thriller, pussycat, writer, hello, counting, ...
# 29  [hollywood, cardi, panda, swalla, swinging, sh...
#
#                                   Representative_Docs
# 0   [ Where do they get off telling you That I am ...
# 1   [ I heard from a friend today And she said you...
# 2   [ I never felt nothing in the world like this ...
# 3   [ Fuck bitches, get money (What?) Fuck niggas,...
# 4   [(That's right) Get up and boogie, get up and ...
# 5   [If you want my lovin' If you really do Don't ...
# 6   [   Okay, check it, check it, check it out It'...
# 7   [ What we gotta do right here is go back Back ...
# 8   [ Ain't another woman that can take your spot,...
# 9   [ Well I see him on the TV Preachin' 'bout the...
# 10  [I'll never let you go Why? Because I love you...
# 11  [ Some nights, I stay up cashing in my bad luc...
# 12  [ Yeah I'm chillin' on a dirt road Laid back s...
# 13  [ Well, you done done me, and you bet I felt i...
# 14  [ Bad boy, bad boy Bad boy, bad boy   Boys wil...
# 15  [ We drop bows on 'em, bows on 'em, when we We...
# 16  [ La que te dijo que un vacío se llena con otr...
# 17  [ Me and all my friends We're all misunderstoo...
# 18  [ It felt like springtime On this February mor...
# 19  [Yeah, I've been throwin' down the whiskey I o...
# 20  [ I've been long, a long way from here Put on ...
# 21  [ Ladies up in here tonight No fighting (We go...
# 22  [ Burn baby burn Burn baby burn Burn baby burn...
# 23  [ Yeah, yeah (Yeah) Yeah, yeah (Yeah) One at a...
# 24  [ Girl, I can't notice but to Notice you, noti...
# 25  [To honor the 25th anniversary of Billboard's ...
# 26  [ It sure is Everyone's trying to get out in t...
# 27  [Do you wanna dance, and hold my hand? Tell me...
# 28  [ It's close to midnight Something evil's lurk...
# 29  [ I'm tryna put you in the worst mood, ah P1 c...

# %%
# Re-visualize the intertopic distance map
fig = general_topic_model.visualize_topics()
fig.show()

# %%
docs_per_topic = general_topic_model.get_representative_docs()
docs_per_topic[28]
# Out:
# [" I'm tryna put you in the worst mood, ah P1 cleaner than your church shoes, ah Milli point two just to hurt you, ah All red Lamb’ just to tease you, ah None of these toys on lease too, ah Made your whole year in a week too, yah Main bitch out your league too, ah Side bitch out of your league too, ah   House so empty, need a centerpiece 20 racks a table cut from ebony Cut that ivory into skinny pieces Then she clean it with her face man I love my baby You talking money, need a hearing aid You talking bout me, I don't see the shade Switch up my style, I take any lane I switch up my cup, I kill any pain   Look what you've done I’m a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy   Every day a nigga try to test me, ah Every day a nigga try to end me, ah Pull off in that Roadster SV, ah Pockets overweight, gettin' hefty, ah Coming for the king, that's a far cry, ah I come alive in the fall time, I No competition, I don't really listen I’m in the blue Mulsanne bumping New Edition   House so empty, need a centerpiece 20 racks a table cut from ebony Cut that ivory into skinny pieces Then she clean it with her face man I love my baby You talking money, need a hearing aid You talking bout me, I don’t see the shade Switch up my style, I take any lane I switch up my cup, I kill any pain   Look what you've done I’m a motherfuckin' starboy Look what you've done I'm a motherfuckin’ starboy   Let a nigga brag Pitt Legend of the fall took the year like a bandit Bought mama a crib and a brand new wagon Now she hit the grocery shop looking lavish Star Trek roof in that Wraith of Khan Girls get loose when they hear this song 100 on the dash get me close to God We don't pray for love, we just pray for cars   House so empty, need a centerpiece 20 racks a table cut from ebony Cut that ivory into skinny pieces Then she clean it with her face man I love my baby You talking money, need a hearing aid You talking 'bout me, I don't see the shade Switch up my style, I take any lane I switch up my cup, I kill any pain   Look what you've done I'm a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy",
#  " Bardi in a 'Rari, diamonds all over my body (30, you a fool for this one) Shinin' all over my body Bardi, put that lil' bitch on molly, Bardi! Bitch on molly (Cheeze) 21, diamonds all over my body Fucked that bitch on molly (KSR) Ask him if I'm 'bout it   Your bitch wanna party with Cardi Cartier Bardi in a 'Rari (21) Diamonds all over my body (Cardi) Shinin' all over my body (My body) Cardi got your bitch on molly Bitch, you ain't gang, you lame Bentley truck lane to lane, blow out the brain (21) I go insane, insane I drop a check on the chain, fuck up a check in the Flame Cardi took your man, you upset, uh Cardi got rich, they upset, yeah (From what?) Cardi put the pussy on Offset (Say what?) Cartier, Cardi B brain on Offset (21) Cardi took your man, you upset, uh Cardi got rich, they upset, yeah (21) Cardi put the pussy on Offset (Cardi) Cartier, Cardi B brain on Offset (Who's Cardi?)   Who get this motherfucker started? (Cardi) Who took your bitch out to party? (Cardi) I took your bitch and departed (Cardi) Who that be fly as a Martian? (Cardi) Who that on fleek in the cut? (Cardi) Who got the bricks in the truck? (Cardi) Them diamonds gon' hit like a bitch on a bitchy ass bitch Bitch, you a wannabe Cardi Red bottom MJ, moonwalk on a bitch Moonwalkin' through your clique I'm moonwalkin' in the 6 Sticky with the kick, moonrocks in this bitch I'm from the motherfuckin' Bronx (Bronx) I keep the pump in the trunk (Trunk) Bitch, if you bad then jump (Jump) Might leave your bitch in a slump (Your back)   Your bitch wanna party with Cardi Cartier Bardi in a 'Rari (21) Diamonds all over my body (Cardi) Shinin' all over my body (My body) Cardi got your bitch on molly Bitch, you ain't gang, you lame Bentley truck lane to lane, blow out the brain (21) I go insane, insane I drop a check on the chain, fuck up a check in the Flame Cardi took your man, you upset, uh Cardi got rich, they upset, yeah (From what?) Cardi put the pussy on Offset (Say what?) Cartier, Cardi B brain on Offset (21) Cardi took your man, you upset, uh Cardi got rich, they upset, yeah (21) Cardi put the pussy on Offset (Cardi) Cartier, Cardi B brain on Offset   Your bitch wanna party with a Savage (21) Saint Laurent Savage in an Aston (Yeah) High end cars and fashion (21) I don't eat pussy, I'm fastin' (On God) I'm a Blood, my brother Crippin' Bitch, I'm drippin', ho, you trippin' Told the waitress, I ain't tippin' I like hot sauce on my chicken (On God) I pulled the rubber off and I put hot sauce on her titties (21) I'm in a Bentley truck, she keep on suckin' like it's tinted (21) All these VVSs, nigga, my sperm worth millions (On God) The bitch so bad, I popped a molly 'fore I hit it (21, 21)   Your bitch wanna party with Cardi Cartier Bardi in a 'Rari (21) Diamonds all over my body (Cardi) Shinin' all over my body (My body) Cardi got your bitch on molly Bitch, you ain't gang, you lame Bentley truck lane to lane, blow out the brain (21) I go insane, insane I drop a check on the chain, fuck up a check in the Flame Cardi took your man, you upset, uh Cardi got rich, they upset, yeah (From what?) Cardi put the pussy on Offset (Say what?) Cartier, Cardi B brain on Offset (21) Cardi took your man, you upset, uh Cardi got rich, they upset, yeah (21) Cardi put the pussy on Offset (Cardi) Cartier, Cardi B brain on Offset (Who's Cardi?)   Step in this bitch in Givenchy (Cash) Fuck up a check in Givenchy (Cash) Boss out the coupe and them inches I fuck up a bag at the Fendi, I fuck up a bag in a minute Who you know drip like this? Who you know built like this? I'm poppin' shit like a dude Pull up to pop at your crew, brrrt, poppin' at you (Woo) They say you basic, I flooded the Rollie with diamonds I flooded the Patek and bracelet I got your bitch and she naked Ice on the cake when I bake it I'm switchin' lanes in the Range Swap out the dick for the brain Swap out your bitch for your main Swap out the trap for the fame Ice on them Cardi B Cartier frames, bitch   Your bitc ...
#  " I'm tryna put you in the worst mood, ah P1 cleaner than your church shoes, ah Milli point two just to hurt you, ah All red Lamb’ just to tease you, ah None of these toys on lease too, ah Made your whole year in a week too, yah Main bitch out your league too, ah Side bitch out of your league too, ah   House so empty, need a centerpiece 20 racks a table cut from ebony Cut that ivory into skinny pieces Then she clean it with her face man I love my baby You talking money, need a hearing aid You talking bout me, I don't see the shade Switch up my style, I take any lane I switch up my cup, I kill any pain   Look what you've done I’m a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy   Every day a nigga try to test me, ah Every day a nigga try to end me, ah Pull off in that Roadster SV, ah Pockets overweight, gettin' hefty, ah Coming for the king, that's a far cry, ah I come alive in the fall time, I No competition, I don't really listen I’m in the blue Mulsanne bumping New Edition   House so empty, need a centerpiece 20 racks a table cut from ebony Cut that ivory into skinny pieces Then she clean it with her face man I love my baby You talking money, need a hearing aid You talking bout me, I don’t see the shade Switch up my style, I take any lane I switch up my cup, I kill any pain   Look what you've done I’m a motherfuckin' starboy Look what you've done I'm a motherfuckin’ starboy   Let a nigga brag Pitt Legend of the fall took the year like a bandit Bought mama a crib and a brand new wagon Now she hit the grocery shop looking lavish Star Trek roof in that Wraith of Khan Girls get loose when they hear this song 100 on the dash get me close to God We don't pray for love, we just pray for cars   House so empty, need a centerpiece 20 racks a table cut from ebony Cut that ivory into skinny pieces Then she clean it with her face man I love my baby You talking money, need a hearing aid You talking 'bout me, I don't see the shade Switch up my style, I take any lane I switch up my cup, I kill any pain   Look what you've done I'm a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy Look what you've done I'm a motherfuckin' starboy"]

# %% [markdown]
# without "love","baby","girl" ---BANNEd

# %%
stopwords_nltk = stopwords.words('english')
general_lyrics_stopwords2 = stopwords_nltk + [
    'la', 'lo', 'lola', 'du', 'oh', 'yeah', 'la la', 'lo lo', 'du du', 'got', 'gonna',
    'ooh', 'get', 'take', 'da', 'know', 'like', 'one', 'said', 'ron',
    'let', 'go', 'come', 'want', 'toke', 'say', 'day', 'good', 'see', 'make',
    'niggas', 'nigga', 'ya', 'choo', 'na', 'uh', 'yuh', 'hmm', 'wanna',
    'doo', 'dat', 'woo', 'nah', 'whoomp', 'yo', 'whoo', 'whatta', 'wa',
    'johnny', 'boaw', 'th', 'whoa', 'eh', 'ooo', 'um', 'dum', 'thy', 'oo',
    'the', 'on', 'and', 'ta', 'pa', 'oop', 'ha', 'bop', 'ah', 'yah', 'shes',
    'aa', 'im', 'ohoh', 'whats', 'huh', 'youre', 'dont', 'self', 'isnt', 'yeh', 
    'jo', 'cant', 'hes', 'uhuh', 'ive', 'yah','hmmmmm','ohh','woulda','nae','lil',
    'chh','ayy','aha','dit','ding','ling','feat','justin','mbabarara','rainin','burnin',
    'em','drake','sylvia','alejandro','love','baby','girl','girls','boy','boys'
]


vectorizer2 = CountVectorizer(
    stop_words=general_lyrics_stopwords2
)

umap_model = UMAP(
    n_neighbors=10,
    n_components=10,
    min_dist=0.0,
    metric="cosine",
    random_state=SEED
)

hdbscan_model = HDBSCAN(  # HDBSCAN is for clustering 
    min_cluster_size=20,   # how many docs per topic (granularity)
    min_samples=10,      # how many clusters are allowed to be formed
    prediction_data=True,
    cluster_selection_method="leaf"  # leaf gives more granular topics
)

general_topic_model2 = BERTopic(    # top level model (compare with HDBSCAN and umap)
    embedding_model="all-distilroberta-v1",   # all-distilroberta-v1
    vectorizer_model=vectorizer2,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    min_topic_size=20,      #if a topic survives HDBSCAN but is below this min_topic_size, it will get merged into another topic
    top_n_words=15,
    calculate_probabilities=True,
    verbose=True
)

topics_general, probs_general = general_topic_model2.fit_transform(docs)
# Reduce the number of topics (set to the number you want)
general_topic_model2.reduce_topics(docs, nr_topics=30)
general_topic_model2.get_topic_info()
# Out:
# 2025-11-23 12:24:46,055 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 196/196 [03:05<00:00,  1.06it/s]
# 2025-11-23 12:27:53,283 - BERTopic - Embedding - Completed ✓
# 2025-11-23 12:27:53,284 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-23 12:27:58,497 - BERTopic - Dimensionality - Completed ✓
# 2025-11-23 12:27:58,498 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-23 12:27:58,746 - BERTopic - Cluster - Completed ✓
# 2025-11-23 12:27:58,748 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-23 12:27:59,170 - BERTopic - Representation - Completed ✓
# 2025-11-23 12:27:59,366 - BERTopic - Topic reduction - Reducing number of topics
# 2025-11-23 12:27:59,370 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-23 12:27:59,778 - BERTopic - Representation - Completed ✓
# 2025-11-23 12:27:59,779 - BERTopic - Topic reduction - Reduced number of topics from 40 to 30
#     Topic  Count                                     Name  \
# 0      -1   4351                  -1_time_cause_never_way
# 1       0    229               0_never_heart_without_away
# 2       1    194                   1_cause_need_back_mind
# 3       2    149                   2_bitch_fuck_shit_back
# 4       3    111                3_boogie_mony_shake_twist
# 5       4     99                    4_lovin_need_mmm_give
# 6       5     99                 5_bay_crank_watch_soulja
# 7       6     96                    6_body_long_way_shake
# 8       7     91               7_chance_woman_man_whatcha
# 9       8     87            8_promise_hope_bright_believe
# 10      9     84                 9_ever_true_always_never
# 11     10     83             10_seeds_running_sowing_wind
# 12     11     53               11_country_little_ride_old
# 13     12     49   12_free_naturally_irresistible_deserve
# 14     13     42                13_boogety_bird_mow_willy
# 15     14     41               14_move_casbah_lights_bows
# 16     15     39                          15_que_de_te_tú
# 17     16     37                   16_happy_run_world_war
# 18     17     35           17_summer_bye_september_sealed
# 19     18     34          18_night_older_somethin_thought
# 20     19     33                  19_dad_says_dandy_glory
# 21     20     29                          20_te_mi_que_se
# 22     21     29                 21_fire_burning_burn_hot
# 23     22     27  22_beach_miami_california_international
# 24     23     25             23_rumour_rumours_call_trust
# 25     24     25                 24_proof_funny_top_swift
# 26     25     23           25_rain_rainy_raindrops_carrie
# 27     26     21             26_dance_music_dancing_night
# 28     27     20        27_thriller_pussycat_writer_hello
# 29     28     20          28_hollywood_cardi_panda_swalla
#
#                                        Representation  \
# 0   [time, cause, never, way, back, right, tell, n...
# 1   [never, heart, without, away, cry, gone, time,...
# 2   [cause, need, back, mind, around, tell, shake,...
# 3   [bitch, fuck, shit, back, gon, money, city, tw...
# 4   [boogie, mony, shake, twist, watch, dance, mus...
# 5   [lovin, need, mmm, give, feel, loving, wo, eve...
# 6   [bay, crank, watch, soulja, wee, work, yuuuuuu...
# 7   [body, long, way, shake, fresh, party, right, ...
# 8   [chance, woman, man, whatcha, mmmm, give, need...
# 9   [promise, hope, bright, believe, church, find,...
# 10  [ever, true, always, never, forever, heart, li...
# 11  [seeds, running, sowing, wind, boat, away, pas...
# 12  [country, little, ride, old, road, free, mama,...
# 13  [free, naturally, irresistible, deserve, obses...
# 14  [boogety, bird, mow, willy, bennie, bang, bad,...
# 15  [move, casbah, lights, bows, insane, batman, s...
# 16  [que, de, te, tú, el, en, ey, como, se, un, mi...
# 17  [happy, run, world, war, waiting, washed, away...
# 18  [summer, bye, september, sealed, sun, bird, go...
# 19  [night, older, somethin, thought, proof, bout,...
# 20  [dad, says, dandy, glory, joyride, laura, make...
# 21  [te, mi, que, se, si, es, pd, quiero, amor, ba...
# 22  [fire, burning, burn, hot, venus, heat, desire...
# 23  [beach, miami, california, international, way,...
# 24  [rumour, rumours, call, trust, wants, knows, h...
# 25  [proof, funny, top, swift, taylor, williams, k...
# 26  [rain, rainy, raindrops, carrie, night, window...
# 27  [dance, music, dancing, night, groove, rhythm,...
# 28  [thriller, pussycat, writer, hello, counting, ...
# 29  [hollywood, cardi, panda, swalla, swinging, sh...
#
#                                   Representative_Docs
# 0   [Oh, darling I'm so lonely without you Can't s...
# 1   [ I heard from a friend today And she said you...
# 2   [ They say around the way you've asked for me ...
# 3   [ Fuck bitches, get money (What?) Fuck niggas,...
# 4   [Boogie Boogie down baby Ooo-uh, boogie Baby, ...
# 5   [ Baby, I need your lovin' Baby, I need your l...
# 6   [   Okay, check it, check it, check it out It'...
# 7   [ Hey, hey   Bed, stay in bed The feeling of y...
# 8   [ Wha-wha-wha-wha-what did you say? (J-J-J-J-J...
# 9   [ Well I see him on the TV Preachin' 'bout the...
# 10  [You know you're everything to me And I could ...
# 11  [ Some nights, I stay up cashing in my bad luc...
# 12  [ Yeah I'm chillin' on a dirt road Laid back s...
# 13  [ Well, you done done me, and you bet I felt i...
# 14  [{Intro}  North side , east side Little Willy,...
# 15  [ We drop bows on 'em, bows on 'em, when we We...
# 16  [ La que te dijo que un vacío se llena con otr...
# 17  [ Me and all my friends We're all misunderstoo...
# 18  [Intro  Though we gotta say goodbye for the su...
# 19  [ Hey, I was doing just fine before I met you ...
# 20  [ I've been long, a long way from here Put on ...
# 21  [ Ladies up in here tonight No fighting (We go...
# 22  [ Burn baby burn Burn baby burn Burn baby burn...
# 23  [ Yeah, yeah (Yeah) Yeah, yeah (Yeah) One at a...
# 24  [ I met this girl late last year She said, "Do...
# 25  [To honor the 25th anniversary of Billboard's ...
# 26  [ It sure is Everyone's trying to get out in t...
# 27  [Do you wanna dance, and hold my hand? Tell me...
# 28  [ It's close to midnight Something evil's lurk...
# 29  [ I'm tryna put you in the worst mood, ah P1 c...

# %%
# Re-visualize the intertopic distance map
fig = general_topic_model2.visualize_topics()
fig.show()
